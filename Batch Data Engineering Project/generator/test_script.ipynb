# %%
ORDERS_MIN = 2000
ORDERS_MAX = 5000
CUSTOMERS_MIN = 10
CUSTOMERS_MAX = 20
PRODUCTS_MIN = 5
PRODUCTS_MAX = 10

REGIONS = ["Mandera East", "Mandera West", "Mandera Central"]
PAYMENT_STATUSES = ["paid", "failed", "pending"]

PRODUCT_CATEGORIES = {
    "Electronics": [
        "Wireless Earbuds", "Power Bank", "USB-C Hub", "Bluetooth Speaker",
        "Smart Watch", "Laptop Stand", "Webcam", "Portable SSD",
        "Phone Case", "Screen Protector",
    ],
    "Groceries": [
        "Rice 5kg", "Cooking Oil 3L", "Sugar 2kg", "Maize Flour 2kg",
        "Tea Leaves 500g", "Milk Powder 900g", "Salt 1kg",
        "Wheat Flour 2kg", "Pasta 500g", "Tomato Paste",
    ],
    "Clothing": [
        "Cotton T-Shirt", "Denim Jeans", "Polo Shirt", "Hoodie",
        "Khaki Trousers", "Sports Shorts", "Formal Shirt",
        "Beanie Hat", "Canvas Shoes", "Leather Belt",
    ],
    "Home & Kitchen": [
        "Water Bottle", "Thermos Flask", "Frying Pan", "Dinner Set",
        "Storage Container", "Cutting Board", "Blender",
        "Kettle", "Mop Set", "Towel Set",
    ],
}

# %%
"""Generates synthetic customer records."""

import random
from datetime import datetime, timezone

from faker import Faker

#from config.settings import CUSTOMERS_MIN, CUSTOMERS_MAX

fake = Faker()


def generate(batch_id: str) -> list[dict]:
    """Generate 10-20 customer documents."""
    count = random.randint(CUSTOMERS_MIN, CUSTOMERS_MAX)
    customers = []

    for _ in range(count):
        customers.append({
            "customer_id": f"CUST{random.randint(10000, 99999)}",
            "name": fake.name(),
            "email": fake.email(),
            "phone": fake.phone_number(),
            "city": fake.city(),
            "batch_id": batch_id,
            "created_at": datetime.now(timezone.utc),
        })

    return customers

print(generate("batch_20240601_120000"))
# Out:
# [{'customer_id': 'CUST86277', 'name': 'Martin Foster', 'email': 'kjohnson@example.net', 'phone': '363-907-3122x79084', 'city': 'Thomasmouth', 'batch_id': 'batch_20240601_120000', 'created_at': datetime.datetime(2026, 4, 18, 10, 42, 34, 187982, tzinfo=datetime.timezone.utc)}, {'customer_id': 'CUST84112', 'name': 'Christopher Calderon', 'email': 'harrischristina@example.net', 'phone': '958-935-0964', 'city': 'Charlesberg', 'batch_id': 'batch_20240601_120000', 'created_at': datetime.datetime(2026, 4, 18, 10, 42, 34, 188803, tzinfo=datetime.timezone.utc)}, {'customer_id': 'CUST10909', 'name': 'Ryan Carroll', 'email': 'tyler13@example.org', 'phone': '(616)782-9136', 'city': 'Carlsonburgh', 'batch_id': 'batch_20240601_120000', 'created_at': datetime.datetime(2026, 4, 18, 10, 42, 34, 189729, tzinfo=datetime.timezone.utc)}, {'customer_id': 'CUST31373', 'name': 'Jordan Schwartz', 'email': 'clarkleslie@example.net', 'phone': '(997)390-0011x29926', 'city': 'Jenniferhaven', 'batch_id': 'batch_20240601_120000', 'created_at': datetime.datetime(2026, 4, 18, 10, 42, 34, 190283, tzinfo=datetime.timezone.utc)}, {'customer_id': 'CUST30906', 'name': 'Monica Baker', 'email': 'whitescott@example.net', 'phone': '201-410-2792x00050', 'city': 'Kathleenland', 'batch_id': 'batch_20240601_120000', 'created_at': datetime.datetime(2026, 4, 18, 10, 42, 34, 190764, tzinfo=datetime.timezone.utc)}, {'customer_id': 'CUST10301', 'name': 'Amy Richards', 'email': 'whitemegan@example.com', 'phone': '405.805.7307x17906', 'city': 'Timothyside', 'batch_id': 'batch_20240601_120000', 'created_at': datetime.datetime(2026, 4, 18, 10, 42, 34, 191231, tzinfo=datetime.timezone.utc)}, {'customer_id': 'CUST68251', 'name': 'William Evans', 'email': 'egibson@example.com', 'phone': '001-872-349-1478x29785', 'city': 'Erinchester', 'batch_id': 'batch_20240601_120000', 'created_at': datetime.datetime(2026, 4, 18, 10, 42, 34, 191633, tzinfo=datetime.timezone.utc)}, {'customer_id': 'CUST62898', 'name': 'Michael Brennan', 'email': 'kristi21@example.net', 'phone': '+1-706-807-9907', 'city': 'Lake Sherry', 'batch_id': 'batch_20240601_120000', 'created_at': datetime.datetime(2026, 4, 18, 10, 42, 34, 192153, tzinfo=datetime.timezone.utc)}, {'customer_id': 'CUST13560', 'name': 'Roberto Bryan', 'email': 'davismichelle@example.net', 'phone': '(695)599-0336x941', 'city': 'Gregoryville', 'batch_id': 'batch_20240601_120000', 'created_at': datetime.datetime(2026, 4, 18, 10, 42, 34, 192644, tzinfo=datetime.timezone.utc)}, {'customer_id': 'CUST70203', 'name': 'Kathleen Allen', 'email': 'hturner@example.net', 'phone': '(261)738-6853x252', 'city': 'Cynthiabury', 'batch_id': 'batch_20240601_120000', 'created_at': datetime.datetime(2026, 4, 18, 10, 42, 34, 193048, tzinfo=datetime.timezone.utc)}, {'customer_id': 'CUST40265', 'name': 'Andre Cook', 'email': 'pmooney@example.org', 'phone': '443-849-5026x24474', 'city': 'Wyattland', 'batch_id': 'batch_20240601_120000', 'created_at': datetime.datetime(2026, 4, 18, 10, 42, 34, 193889, tzinfo=datetime.timezone.utc)}, {'customer_id': 'CUST85146', 'name': 'Paul Bennett', 'email': 'daniel75@example.net', 'phone': '(425)981-3853', 'city': 'Chavezton', 'batch_id': 'batch_20240601_120000', 'created_at': datetime.datetime(2026, 4, 18, 10, 42, 34, 194429, tzinfo=datetime.timezone.utc)}, {'customer_id': 'CUST70277', 'name': 'Jennifer Montes', 'email': 'tonya86@example.org', 'phone': '802-865-7538x58792', 'city': 'Danaville', 'batch_id': 'batch_20240601_120000', 'created_at': datetime.datetime(2026, 4, 18, 10, 42, 34, 194821, tzinfo=datetime.timezone.utc)}, {'customer_id': 'CUST31607', 'name': 'Daniel Richardson', 'email': 'uwright@example.net', 'phone': '(291)412-5729x22428', 'city': 'Williamport', 'batch_id': 'batch_20240601_120000', 'created_at': datetime.datetime(2026, 4, 18, 10, 42, 34, 195226, tzinfo=datetime.timezone.utc)}, {'customer_id': 'CUST62748', 'name': 'Stephen Hancock', 'email': 'beckyprice@example.org', 'phone': '326.923.9842x52096', 'city': 'West Willi ...

# %%
"""Generates synthetic product records."""

import random
from datetime import datetime, timezone

#from config.settings import PRODUCTS_MIN, PRODUCTS_MAX, PRODUCT_CATEGORIES


def generate(batch_id: str) -> list[dict]:
    """Generate 5-10 product documents."""
    count = random.randint(PRODUCTS_MIN, PRODUCTS_MAX)
    products = []

    for _ in range(count):
        category = random.choice(list(PRODUCT_CATEGORIES.keys()))
        products.append({
            "product_id": f"PROD{random.randint(1000, 9999)}",
            "product_name": random.choice(PRODUCT_CATEGORIES[category]),
            "category": category,
            "price": round(random.uniform(50, 15000), 2),
            "batch_id": batch_id,
            "created_at": datetime.now(timezone.utc),
        })

    return products

# %%
"""Generates synthetic order records."""

import random
from datetime import datetime, timezone

#from config.settings import ORDERS_MIN, ORDERS_MAX, REGIONS, PAYMENT_STATUSES


def generate(customer_ids: list[str], product_ids: list[str], batch_id: str) -> list[dict]:
    """Generate 2000-5000 order documents referencing existing customers and products."""
    count = random.randint(ORDERS_MIN, ORDERS_MAX)
    orders = []

    for _ in range(count):
        orders.append({
            "order_id": f"ORD{random.randint(10000, 99999)}",
            "customer_id": random.choice(customer_ids),
            "product_id": random.choice(product_ids),
            "region": random.choice(REGIONS),
            "amount": random.randint(1000, 50000),
            "payment_status": random.choice(PAYMENT_STATUSES),
            "batch_id": batch_id,
            "created_at": datetime.now(timezone.utc),
        })

    return orders
